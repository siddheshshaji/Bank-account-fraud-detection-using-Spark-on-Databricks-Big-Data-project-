# %%
# %sql
create database if not exists bankdf
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
use bankdf
--drop table df
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql 
CREATE table bankdf.df
USING CSV
OPTIONS (path "s3://bankfrauddata/output.csv", header "true");
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select count(*) from df
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>4238937</td></tr></tbody></table></div>

# %%
# %sql
SELECT * from df limit 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT fraud_bool, source, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, source
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fraud_bool</th><th>source</th><th>count(1)</th><th>percentage</th></tr></thead><tbody><tr><td>1</td><td>INTERNET</td><td>49899</td><td>99.00595238095238</td></tr><tr><td>1</td><td>TELEAPP</td><td>501</td><td>0.99404761904762</td></tr><tr><td>0</td><td>INTERNET</td><td>4157466</td><td>99.25818967338715</td></tr><tr><td>0</td><td>TELEAPP</td><td>31071</td><td>0.74181032661285</td></tr></tbody></table></div>

# %%
# %sql
SELECT fraud_bool, device_os, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, device_os
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT fraud_bool, phone_home_valid, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, phone_home_valid
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fraud_bool</th><th>phone_home_valid</th><th>count(1)</th><th>percentage</th></tr></thead><tbody><tr><td>1</td><td>0</td><td>36744</td><td>72.90476190476190</td></tr><tr><td>1</td><td>1</td><td>13656</td><td>27.09523809523810</td></tr><tr><td>0</td><td>0</td><td>2225733</td><td>53.13867347954668</td></tr><tr><td>0</td><td>1</td><td>1962804</td><td>46.86132652045332</td></tr></tbody></table></div>

# %%
# %sql
SELECT fraud_bool, phone_mobile_valid, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, phone_mobile_valid
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fraud_bool</th><th>phone_mobile_valid</th><th>count(1)</th><th>percentage</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>42231</td><td>83.79166666666667</td></tr><tr><td>1</td><td>0</td><td>8169</td><td>16.20833333333333</td></tr><tr><td>0</td><td>1</td><td>3639577</td><td>86.89375311713851</td></tr><tr><td>0</td><td>0</td><td>548960</td><td>13.10624688286149</td></tr></tbody></table></div>

# %%
# %sql
SELECT fraud_bool, income, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, income
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT fraud_bool, customer_age, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, customer_age
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT fraud_bool, email_is_free, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, email_is_free
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fraud_bool</th><th>email_is_free</th><th>count(1)</th><th>percentage</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>33025</td><td>65.52579365079365</td></tr><tr><td>1</td><td>0</td><td>17375</td><td>34.47420634920635</td></tr><tr><td>0</td><td>1</td><td>2183680</td><td>52.13467136615959</td></tr><tr><td>0</td><td>0</td><td>2004857</td><td>47.86532863384041</td></tr></tbody></table></div>

# %%
# %sql
SELECT fraud_bool, has_other_cards, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, has_other_cards
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fraud_bool</th><th>has_other_cards</th><th>count(1)</th><th>percentage</th></tr></thead><tbody><tr><td>1</td><td>0</td><td>45872</td><td>91.01587301587302</td></tr><tr><td>1</td><td>1</td><td>4528</td><td>8.98412698412698</td></tr><tr><td>0</td><td>0</td><td>3178011</td><td>75.87401042416481</td></tr><tr><td>0</td><td>1</td><td>1010526</td><td>24.12598957583519</td></tr></tbody></table></div>

# %%
# %sql
SELECT fraud_bool, foreign_request, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, foreign_request
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fraud_bool</th><th>foreign_request</th><th>count(1)</th><th>percentage</th></tr></thead><tbody><tr><td>1</td><td>0</td><td>47991</td><td>95.22023809523810</td></tr><tr><td>1</td><td>1</td><td>2409</td><td>4.77976190476190</td></tr><tr><td>0</td><td>0</td><td>4087436</td><td>97.58624550767965</td></tr><tr><td>0</td><td>1</td><td>101101</td><td>2.41375449232035</td></tr></tbody></table></div>

# %%
# %sql
SELECT fraud_bool, employment_status, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, employment_status
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT fraud_bool, housing_status, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, housing_status
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT fraud_bool, payment_type, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, payment_type
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT fraud_bool, source, device_os, phone_home_valid, phone_mobile_valid, foreign_request, payment_type,housing_status, employment_status,has_other_cards, income, COUNT(*), 
100.0 * COUNT(*) / SUM(COUNT(*)) OVER (partition by fraud_bool) AS percentage
FROM df
GROUP BY fraud_bool, source, device_os, phone_home_valid, phone_mobile_valid, foreign_request, payment_type,housing_status, employment_status,has_other_cards, income
ORDER BY fraud_bool desc, percentage desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
import boto3
import io
import pandas as pd
import matplotlib.pyplot as plt

# %%
s3 = boto3.client('s3')
obj = s3.get_object(Bucket='bankfrauddata', Key='output.csv')

# %%
df = pd.read_csv(io.BytesIO(obj['Body'].read()))

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['source'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['device_os'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['phone_home_valid'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['phone_mobile_valid'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['income'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['customer_age'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['email_is_free'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['has_other_cards'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['foreign_request'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['employment_status'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['housing_status'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
cross_tab_prop = pd.crosstab(index=df['fraud_bool'],
                             columns=df['payment_type'],
                             normalize="index")

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    figsize=(10, 6))

plt.legend(loc="lower left", ncol=2)
plt.xlabel("Release Year")
plt.ylabel("Proportion")
plt.show()

# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=6390691545043401#setting/sparkui/1223-003951-333x7lmo/driver-139124915385729472">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
spdf = sc.textFile('s3://bankfrauddata/output.csv')

# %%
spdf.take(3)
# Out:
# Out[6]: ['fraud_bool,income,name_email_similarity,prev_address_months_count,current_address_months_count,customer_age,days_since_request,intended_balcon_amount,payment_type,zip_count_4w,velocity_6h,velocity_24h,velocity_4w,bank_branch_count_8w,date_of_birth_distinct_emails_4w,employment_status,credit_risk_score,email_is_free,housing_status,phone_home_valid,phone_mobile_valid,bank_months_count,has_other_cards,proposed_credit_limit,foreign_request,source,session_length_in_minutes,device_os,keep_alive_session,device_distinct_emails_8w,device_fraud_count,month,x1,x2',
#  '1,0.9,0.1668277344243326,-1,88,50,0.0209251728365947,-1.3313449634902534,AA,769,10650.765522770173,3134.319630490106,3863.647739528353,1,6,CA,185,0,BA,1,0,24,0,500.0,0,INTERNET,3.888114604789093,windows,0,1,0,7,,',
# ...

# %%
rdd = sc.parallelize(df)

# %%
rdd.count()
# Out:
# Out[12]: 34

# %%
rdd.getNumPartitions()
# Out:
# Out[15]: 2
